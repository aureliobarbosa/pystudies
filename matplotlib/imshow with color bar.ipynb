# %%
import matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility
np.random.seed(19680801)

# %%
plt.subplot(211)
plt.imshow(np.random.random((100, 100)), cmap=plt.cm.BuPu_r)
plt.subplot(212)
plt.imshow(np.random.random((100, 100)), cmap=plt.cm.BuPu_r)

plt.subplots_adjust(bottom=0.1, right=0.8,top=0.9)
#plt.subplots_adjust(bottom=0.1, right=0.8, top=0.9)
#cax = plt.axes([0.7, 0.1, 0.075, 0.8])
plt.colorbar(cax=cax)
plt.show()

# %%
vshape = (2,3)
vshape_x = tuple(range(vshape[0]))
vshape_y = tuple(range(vshape[1]))
[(x,y) for x in vshape_x for y in vshape_y]
# Out:
# [(0, 0), (0, 1), (0, 2), (1, 0), (1, 1), (1, 2)]

# %%
# Out:
# [0, 1, 2]

# %%
fig, ax = plt.subplots(nrows=2,ncols=2)

cmap = mpl.colors.LinearSegmentedColormap.from_list('my_colormap', ['white','yellow','red'], 
                                           256)

img0 = plt.imshow(viral_load_0,interpolation='nearest',
                    cmap = cmap, vmin=0.0, vmax=10.0,
                    origin='lower')

plt.colorbar(img0,cmap=cmap)
plt.title("Viral load at t=0")
# Out:
# Text(0.5, 1.0, 'Viral load at t=0')

# %%
[(x,y) for x in range(shape[0]) ]
