# %% [markdown]
# # 0. Introdução ao Jupyter Lab
# ---
#
# %Inserir logo do Jupyter Lab aqui
#
# O Jupyter Lab é uma plataforma integrada de desenvolvimento (IDE, do inglês Integrated Development Environment), que é utilizada para programar em Python, analisar dados (tanto em modo gráfico quanto os dados em si), juntamente com Jupyter Notebooks (que é um formato de arquivo para computação interativa, com resultados similares aos obtidos em Maple e Mathematica, embora a abordagem seja diferente da implementada por estes).
#
# O Jupyter Lab utiliza o Kernel IPython para executar aplicações em Python e permite a inclusão de trechos de texto no formato Markdown, sendo que este, por sua vez, permite a inclusão de uma gama muito grande de conteúdo, incluindo equações em LaTeX, código HTML, figuras, etc. A sintaxe do  Markdown é extremamente simples e será discutida brevemente abaixo. É interessante notar que outros Kernels são suportados pelo Jupyter Lab (p. ex. R, Java, C, C++, gnuplot), mas a inclusão destes kernels foge ao escopo deste pequeno tutorial.
#
# Mais informações sobre o Jupyter Lab podem ser obtidas na [documentação do projeto](http://jupyterlab.readthedocs.io/en/stable/index.html).
#
# Neste tutorial estou interessado e m mostrar como usar o Jupyter Lab como plataforma para implementar um pequeno projeto de pesquisa, ou uma aula, em  IPython Notebooks. Neste mem modo gráfico quanto os dados em si), juntamente com Jupyter Notebooks (que é um formato de arquivo para computação interativa, com resultados similares aos obtidos em Maple e Mathematica, embora a abordagem seja diferente da implementada por estes).
#
# No momento tenho dois projetos básicos em mente (vamos ver qual deles será implementado primeiro):
#
# * Equação de van der Waals
#
# * Modelo de Ising
#
# Mas antes de prosseguir, vamos começar do começo!

# %% [markdown]
# ## 1. Instalação
# ---
#
# (Inserir logo e link do Fedora e do Anaconda, aqui!)
#
# Estou utilizando Fedora, então, todas as recomendações são para a instalação em ambiente deste tipo ou derivados dele.
#
# Existem vários caminhos para instalar um ambiente completo do JupyterLab, mas o que eu utilizei (sem realizar muitas pesquisas) foi a instalação do gerenciador de ambientes Anaconda. Você pode baixar o pacote [aqui](https://www.anaconda.com/download/#linux) e obter mair informações [neste lugar](https://www.anaconda.com/what-is-anaconda/). Após ser feita a instalação do Anaconda, rode
# ```
# $ anaconda-navigator
# ```
#
# ou, se preferir:
#
# ```
# $ nohup anaconda-navigator &
# ```
# para desvincular a execução do aplicativo do terminal corrente (como processo filho) e rodar em segundo plano.
#
# (inserir a figura de tela do Anaconda aqui!)

# %% [markdown]
# ## 2. Notebooks
# ---
#
# ### 2.1 Markdown Language Syntax
# ---
#
# O formato Markdown foi criado em 2004 por John Grueber e Aaron Schwartz para uso em fóruns, wikis, manuais de software, entre outros contextos, de forma que os usuários possam introduzir a formatação de maneira simples, rápida e elegante, sem comprometer a legibilidade do texto Markdown puro, *i.e.*, antes de processamento gráfico ou conversão em HTML. Elaborei este pequeno tutorial para apresentar a linguagem para alunos de cursos básicos de computação e simulação computacional (também com o intuito de melhorar meus conhecimentos acerca do formato).
#
# Somente vou indicar brevemente alguns recursos do Markdown, a título de ilustração. Os recursos mais básicos do formato podem ser encontrados aqui
# [aqui](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet#lines) e uma boa descrição está na [Wikipedia](https://en.wikipedia.org/wiki/Markdown). Aspectos mais avançados e extensões podem ser encontrados [neste post GitHub](https://github.com/mundimark/awesome-markdown).
#
# #### 2.1.1 Título
#
#  São criados usando **cerquilhas**, \#, como trecho  abaixo:
# ```
# # Título 1
# ## Título 2
# ### Título 3
# ```
# que produz o seguinte resultado:
#
# # Título 1
# ## Título 2
# ### Título 3
#
# #### 2.1.2 Formatação: negrito e itálico
#
# É muito fácil deixar um texto em negrito ou itálico, basta abrir e fechar o texto com um ou dois asteriscos, como abaixo:
#
# ```
#  *Texto em Itálico*
#  **Texto em negrito**
# ```
#
# *Texto em Itálico*
# **Texto em negrito**
#
#
# #### 2.1.3 Citações
#
# Você pode utilizar crases para marcar uma citação ao longo do texto. Por exemplo, Einstein costuma dizer que `Deus não joga dados!`, que pode ser obtida da seguinte forma:
#
# ```
# Einstein costuma dizer que `Deus não joga dados!`
# ```
#
# O trecho acima é um bloco de citação que pode ser construído utilizando-se três crases, da seguinte maneira
#
# >\`\`\`
# > Einstein costuma dizer que \`Deus não joga dados!\`
# >\`\`\`
#
# Note que eu usei um esquema diferente (não consegui descobrir como citar três crases em uma citação! Se alguém souber, me avise.). Você também pode  uma citação em um bloco de texto utilizando \>, como feito acima, utilizando o caracter \>, como abaixo:
#
# `> Citação em bloco de texto.`
#
# > Citação em bloco de texto.
#
#
#
# Bem, por enquanto é isso. Este tutorial está crescendo devagarinho.
